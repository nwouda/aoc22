# %%
def get_distance(a, b):
    c = a-b
    if c < 0:
        c = 0-c
    return c

def move_rope(h, t)
    for i, tail in enumerate(t):
        if i == 0:
            tail[i] = get_direction('')

def get_direction(h, t):
    hdist = get_distance(h['x'], t['x'])
    vdist = get_distance(h['y'], t['y'])
    if hdist == 1 and vdist == 1:
        print('DO NOTHING')
        return t
    elif hdist > 0 and vdist > 0:
        print('SHOULD MOVE DIAGONALLY')
        print(f'HORIZONTAL {h["x"]-t["x"]}')
        dt = t
        if h["x"] > t["x"]:
            print('Moving tail right')
            dt = { 'x': dt['x']+1, 'y': dt['y'] }
        else:
            print('Moving tail left')
            dt = { 'x': dt['x']-1, 'y': dt['y'] }
        print(f'VERTICAL {h["y"]-t["y"]}')
        if h["y"] > t["y"]:
            print('Moving tail up')
            dt = { 'x': dt['x'], 'y': dt['y']+1 }
        else:
            print('Moving tail down')
            dt = { 'x': dt['x'], 'y': dt['y']-1 }
        return dt
    elif hdist > 1 or vdist > 1:
        if hdist > vdist:
            # print(f'HORIZONTAL {h["x"]-t["x"]}')
            if h["x"] > t["x"]:
                print('Moving tail right')
                return { 'x': t['x']+1, 'y': t['y'] }
            else:
                print('Moving tail left')
                return { 'x': t['x']-1, 'y': t['y'] }
        else:
            # print(f'VERTICAL {h["y"]-t["y"]}')
            if h["y"] > t["y"]:
                print('Moving tail up')
                return { 'x': t['x'], 'y': t['y']+1 }
            else:
                print('Moving tail down')
                return { 'x': t['x'], 'y': t['y']-1 }
    else:
        return t
        # print('Not enough distance to move')

# %%
input = open('9.example', 'r')
lines = list(input.readlines())

# %%
xmax = 0
xmin = 0
ymax = 0
ymin = 0
x = 0
y = 0

height = 0
width = 0
for line in lines:
    line = line.rstrip('\n')
    direction = line.split(' ')[0]
    steps = int(line.split(' ')[1])
    if direction == 'R':
        x += steps
    if direction == 'L':
        x -= steps
    if direction == 'U':
        y += steps
    if direction == 'D':
        y -= steps
    xmax = max(xmax, x)
    xmin = min(xmin, x)
    ymax = max(ymax, y)
    ymin = min(ymin, y)

width = get_distance(xmin, xmax)+1
height = get_distance(ymin, ymax)+1
# print(f'Field x={width} y={height}')

# %%
def draw(width, height, head, tail):
    for y in range(0, height):
        for x in range(0, width):
            if head == { 'x': x, 'y': y }:
                print('H', end='', flush=False)
            elif tail == { 'x': x, 'y': y }:
                print('T', end='', flush=False)
            else:
                print('.', end='', flush=False)
        print('', flush=False)
    print('', flush=True)

# %%
positions = []
tailp = []
tail = [
    { 'x': 0, 'y': 0},
    { 'x': 0, 'y': 0},
    { 'x': 0, 'y': 0},
    { 'x': 0, 'y': 0},
    { 'x': 0, 'y': 0},
    { 'x': 0, 'y': 0},
    { 'x': 0, 'y': 0},
    { 'x': 0, 'y': 0},
    { 'x': 0, 'y': 0},
]
head = { 'x': 0, 'y': 0}
from time import sleep
for line in lines:
    line = line.rstrip('\n')
    direction = line.split(' ')[0]
    steps = int(line.split(' ')[1])
    for step in range(1, steps+1):
        if direction == 'U':
            head = {
                'x': head['x'],
                'y': head['y']+1
            }
        if direction == 'R':
            head = {
                'x': head['x']+1,
                'y': head['y']
            }
        if direction == 'D':
            head = {
                'x': head['x'],
                'y': head['y']-1
            }
        if direction == 'L':
            head = {
                'x': head['x']-1,
                'y': head['y']
            }
        # print(f'moving {direction} step {step}')
        # print(f'Head at {head}')
        tail = get_direction(head, tail)
        # print(f'Tail at {tail}')
        positions.append(str(tail['x'])+'x'+str(tail['y']))
        # draw(width, height, head, tail)
        # sleep(0.5)
        

from pprint import pprint  
pprint(positions)
print(set(positions))
print(len(set(positions)))
# Out:
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# DO NOTHING
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# DO NOTHING
# DO NOTHING
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# DO NOTHING
# DO NOTHING
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# DO NOTHING
# Moving tail right
# Moving tail right
# DO NOTHING
# DO NOTHING
# Moving tail left
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail up
# DO NOTHING
# DO NOTHING
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# Moving tail up
# DO NOTHING
# DO NOTHING
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# DO NOTHING
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail down
# Moving tail right
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# DO NOTHING
# DO NOTHING
# DO NOTHING
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail up
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail down
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# DO NOTHING
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# DO NOTHING
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# DO NOTHING
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail down
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail right
# DO NOTHING
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail right
# Moving tail right
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail up
# Moving tail up
# Moving tail down
# Moving tail down
# Moving tail up
# Moving tail down
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# Moving tail down
# Moving tail down
# Moving tail up
# Moving tail up
# Moving tail down
# Moving tail down
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail down
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# DO NOTHING
# DO NOTHING
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail right
# Moving tail up
# Moving tail up
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail right
# DO NOTHING
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL 2
# Moving tail up
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail up
# Moving tail up
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL -1
# Moving tail down
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail right
# Moving tail right
# Moving tail right
# Moving tail left
# Moving tail right
# Moving tail right
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail up
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -2
# Moving tail left
# VERTICAL 1
# Moving tail up
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL -1
# Moving tail down
# Moving tail right
# Moving tail right
# Moving tail left
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL -1
# Moving tail left
# VERTICAL -2
# Moving tail down
# Moving tail down
# Moving tail down
# Moving tail down
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 2
# Moving tail right
# VERTICAL 1
# Moving tail up
# Moving tail right
# Moving tail right
# DO NOTHING
# SHOULD MOVE DIAGONALLY
# HORIZONTAL 1
# Moving tail right
# VERTICAL 2
# Moving tail up
# Moving tail up
# Moving tail up
# Moving tail up
# ...
#  '10x-161',
#  '9x-162',
#  '8x-162',
#  '7x-162',
#  '6x-162',
#  '5x-162',
#  '4x-162',
#  '3x-162',
#  '2x-162',
#  '1x-162',
#  '1x-162',
#  '0x-161',
#  '0x-160',
#  '0x-159',
#  '0x-158',
#  '0x-157',
#  '0x-156',
#  '0x-156',
#  '0x-156',
#  '0x-157',
#  '0x-158',
#  '0x-159',
#  '0x-160',
#  '0x-161',
#  '0x-162',
#  '0x-163',
#  '0x-164',
#  '0x-165',
#  '0x-165',
#  '-1x-166',
#  '-2x-166',
#  '-3x-166',
#  '-4x-166',
#  '-5x-166',
#  '-6x-166',
#  '-7x-166',
#  '-8x-166',
#  '-9x-166',
#  '-10x-166',
#  '-11x-166',
#  '-12x-166',
#  '-13x-166',
#  '-14x-166',
#  '-14x-166',
#  '-15x-165',
#  '-15x-164',
#  '-15x-163',
#  '-15x-162',
#  '-15x-161',
#  '-15x-160',
#  '-15x-159',
#  '-15x-158',
#  '-15x-157',
#  '-15x-156',
#  '-15x-155',
#  '-15x-155',
#  '-16x-154',
#  '-17x-154',
#  '-18x-154',
#  '-19x-154',
#  '-20x-154',
#  '-20x-154',
#  '-21x-155',
#  '-21x-156',
#  '-21x-157',
#  '-21x-158',
#  '-21x-159',
#  '-21x-159',
#  '-22x-160',
#  '-23x-160',
#  '-24x-160',
#  '-25x-160',
#  '-26x-160',
#  '-27x-160',
#  '-28x-160',
#  '-29x-160',
#  '-30x-160',
#  '-31x-160',
#  '-32x-160',
#  '-33x-160',
#  '-34x-160',
#  '-34x-160',
#  '-35x-159',
#  '-35x-158',
#  '-35x-157',
#  '-35x-156',
#  '-35x-155',
#  '-35x-154',
#  '-35x-153',
#  '-35x-152',
#  '-35x-151',
#  '-35x-150',
#  '-35x-149',
#  '-35x-148',
#  '-35x-147',
#  '-35x-146',
#  '-35x-145',
#  '-35x-144',
#  '-35x-144',
#  '-36x-143',
#  '-37x-143',
#  '-38x-143',
#  '-39x-143',
#  '-40x-143',
#  '-41x-143',
#  '-41x-143',
#  '-42x-144',
#  '-42x-144',
#  '-43x-145',
#  '-44x-145',
#  '-45x-145',
#  '-46x-145',
#  '-47x-145',
#  '-48x-145',
#  '-48x-145',
#  '-49x-144',
#  '-49x-143',
#  '-49x-142',
#  '-49x-141',
#  '-49x-140',
#  '-49x-139',
#  '-49x-138',
#  '-49x-137',
#  '-49x-136',
#  '-49x-135',
#  '-49x-134',
#  '-49x-134',
#  '-50x-133',
#  '-51x-133',
#  '-52x-133',
#  '-53x-133',
#  '-54x-133',
#  '-55x-133',
#  '-56x-133',
#  '-57x-133',
#  '-58x-133',
#  '-59x-133',
#  '-60x-133',
#  '-61x-133',
#  '-62x-133',
#  '-63x-133',
#  '-64x-133',
#  '-65x-133',
#  '-65x-133',
#  '-65x-133',
#  '-64x-133',
#  '-63x-133',
#  '-62x-133',
#  '-61x-133',
#  '-60x-133',
#  '-59x-133',
#  '-58x-133',
#  '-57x-133',
#  '-56x-133',
#  '-55x-133',
#  '-54x-133',
#  '-53x-133',
#  '-52x-133',
#  '-51x-133',
#  '-51x-133',
#  '-50x-132',
#  '-50x-131',
#  '-50x-130',
#  '-50x-129',
#  '-50x-128',
#  '-50x-127',
#  '-50x-126',
#  '-50x-125',
#  '-50x-124',
#  '-50x-123',
#  '-50x-122',
#  '-50x-121',
#  '-50x-120',
#  '-50x-119',
#  '-50x-118',
#  '-50x-117',
#  '-50x-116',
#  '-50x-115',
#  '-50x-115',
#  '-51x-114',
#  '-52x-114',
#  '-53x-114',
#  '-54x-114',
#  '-55x-114',
#  '-56x-114',
#  '-57x-114',
#  '-58x-114',
#  '-59x-114',
#  '-60x-114',
#  '-61x-114',
#  '-61x-114',
#  '-62x-113',
#  '-62x-112',
#  '-62x-111',
#  '-62x-110',
#  '-62x-109',
#  '-62x-108',
#  '-62x-107',
#  '-62x-106',
#  '-62x-105',
#  '-62x-105',
#  '-63x-104',
#  '-64x-104',
#  '-65x-104',
#  '-66x-104',
#  '-67x-104',
#  '-67x-104',
#  '-68x-103',
#  '-68x-102',
#  '-68x-102',
#  '-68x-102',
#  '-68x-103',
#  '-68x-104',
#  '-68x-105',
#  '-68x-106',
#  '-68x-107',
#  '-68x-108',
#  '-68x-109',
#  '-68x-110',
#  '-68x-111',
#  '-68x-112',
#  '-68x-113',
#  '-68x-114',
#  '-68x-115',
#  '-68x-116',
#  '-68x-116',
#  '-69x-117',
#  '-70x-117',
#  '-71x-117',
#  '-72x-117',
#  '-72x-117',
#  '-73x-118',
#  '-73x-119',
#  '-73x-120',
#  '-73x-121',
#  '-73x-122',
#  '-73x-123',
#  '-73x-124',
#  '-73x-125',
#  '-73x-126',
#  '-73x-127',
#  '-73x-128',
#  '-73x-129',
#  '-73x-130',
#  '-73x-131',
#  '-73x-131',
#  '-74x-132',
#  '-75x-132',
#  '-76x-132',
#  '-77x-132',
#  '-78x-132',
#  '-79x-132',
#  '-79x-132',
#  '-79x-132',
#  '-78x-132',
#  '-77x-132',
#  '-76x-132',
#  '-75x-132',
#  '-75x-132',
#  '-74x-133',
#  '-74x-133',
#  '-73x-134',
#  '-72x-134',
#  '-71x-134',
#  '-70x-134',
#  '-69x-134',
#  '-68x-134',
#  '-67x-134',
#  '-66x-134',
#  '-65x-134',
#  '-64x-134',
#  '-63x-134',
#  '-62x-134',
#  '-61x-134',
#  '-60x-134',
#  '-59x-134',
#  '-58x-134',
#  '-57x-134',
#  '-56x-134',
#  '-56x-134',
#  '-56x-134',
#  '-57x-134',
#  '-58x-134',
#  '-58x-134',
#  '-59x-135',
#  '-59x-136',
#  '-59x-137',
#  '-59x-138',
#  '-59x-139',
#  '-59x-140',
#  '-59x-141',
#  '-59x-142',
#  '-59x-143',
#  '-59x-144',
#  '-59x-145',
#  '-59x-146',
#  '-59x-147',
#  '-59x-148',
#  '-59x-149',
#  '-59x-150',
#  '-59x-151',
#  '-59x-151',
#  '-58x-152',
#  '-57x-152',
#  '-56x-152',
#  '-55x-152',
#  '-54x-152',
#  '-53x-152',
#  '-52x-152',
#  '-51x-152',
#  '-50x-152',
#  '-49x-152',
#  '-48x-152',
#  '-47x-152',
#  '-46x-152',
#  '-45x-152',
#  '-44x-152',
#  '-43x-152',
#  '-42x-152',
#  '-41x-152',
#  '-41x-152',
#  '-40x-153',
#  '-40x-154',
#  '-40x-155',
#  '-40x-156',
#  '-40x-157',
#  '-40x-158',
#  '-40x-159',
#  '-40x-160',
#  '-40x-160',
#  '-39x-161',
#  '-38x-161',
#  '-37x-161',
#  '-36x-161',
#  '-35x-161',
#  '-34x-161',
#  '-33x-161',
#  '-32x-161',
#  '-31x-161',
#  '-30x-161',
#  '-30x-161',
#  '-30x-161',
#  '-31x-161',
#  '-32x-161',
#  '-33x-161',
#  '-34x-161',
#  '-35x-161',
#  '-36x-161',
#  '-37x-161',
#  '-38x-161',
#  '-39x-161',
#  '-40x-161',
#  '-41x-161',
#  '-42x-161',
#  '-43x-161',
#  '-44x-161',
#  '-45x-161',
#  '-45x-161',
#  '-45x-161',
#  '-45x-160',
#  '-45x-159',
#  '-45x-158',
#  '-45x-157',
#  '-45x-156',
#  '-45x-155',
#  '-45x-154',
#  '-45x-153',
#  '-45x-152',
#  '-45x-151',
#  '-45x-150',
#  '-45x-149',
#  '-45x-148',
#  '-45x-147',
#  '-45x-147',
#  '-44x-146',
#  '-43x-146',
#  '-43x-146',
#  '-42x-147',
#  '-42x-148',
#  '-42x-149',
#  '-42x-150',
#  '-42x-151',
#  '-42x-152',
#  '-42x-153',
#  '-42x-154',
#  '-42x-155',
#  '-42x-156',
#  '-42x-157',
#  '-42x-158',
#  '-42x-159',
#  '-42x-160',
#  '-42x-161',
#  '-42x-162',
#  '-42x-163',
#  '-42x-163',
#  '-43x-164',
#  '-44x-164',
#  '-45x-164',
#  '-46x-164',
#  '-47x-164',
#  '-48x-164',
#  '-49x-164',
#  '-50x-164',
#  '-51x-164',
#  '-52x-164',
#  '-53x-164',
#  '-54x-164',
#  '-54x-164',
#  '-55x-163',
#  '-55x-162',
#  '-55x-161',
#  '-55x-160',
#  '-55x-159',
#  '-55x-158',
#  '-55x-158',
#  '-55x-158',
#  '-55x-159',
#  '-55x-160',
#  '-55x-161',
#  '-55x-162',
#  '-55x-163',
#  '-55x-163',
#  '-54x-164',
#  '-53x-164',
#  '-52x-164',
#  '-51x-164',
#  '-50x-164',
#  '-49x-164',
#  '-48x-164',
#  '-47x-164',
#  '-46x-164',
#  '-45x-164',
#  '-44x-164',
#  '-43x-164',
#  '-42x-164',
#  '-41x-164',
#  '-41x-164',
#  '-40x-163',
#  '-40x-162',
#  '-40x-161',
#  '-40x-161',
#  '-40x-161',
#  '-40x-162',
#  '-40x-163',
#  '-40x-164',
#  '-40x-165',
#  '-40x-166',
#  '-40x-167',
#  '-40x-168',
#  '-40x-169',
#  '-40x-170',
#  '-40x-171',
#  '-40x-172',
#  '-40x-173',
#  '-40x-174',
#  '-40x-175',
#  '-40x-175',
#  '-39x-176',
#  '-38x-176',
#  '-37x-176',
#  '-36x-176',
#  '-35x-176',
#  '-35x-176',
#  '-34x-175',
#  '-34x-174',
#  '-34x-173',
#  '-34x-173',
#  '-33x-172',
#  '-32x-172',
#  '-31x-172',
#  '-30x-172',
#  '-29x-172',
#  '-28x-172',
#  '-27x-172',
#  '-26x-172',
#  '-25x-172',
#  '-25x-172',
#  '-24x-171',
#  '-24x-170',
#  '-24x-169',
#  '-24x-168',
#  '-24x-167',
#  '-24x-166',
#  '-24x-165',
#  '-24x-164',
#  '-24x-163',
#  '-24x-163',
#  '-24x-163',
#  '-24x-163',
#  '-23x-164',
#  '-23x-165',
#  '-23x-166',
#  '-23x-167',
#  '-23x-168',
#  '-23x-169',
#  '-23x-170',
#  '-23x-171',
#  '-23x-172',
#  '-23x-173',
#  '-23x-174',
#  '-23x-175',
#  '-23x-176',
#  '-23x-177',
#  '-23x-178',
#  '-23x-179',
#  '-23x-180',
#  '-23x-180',
#  '-22x-181',
#  '-21x-181',
#  '-20x-181',
#  '-19x-181',
#  '-18x-181',
#  '-17x-181',
#  '-16x-181',
#  '-15x-181',
#  '-14x-181',
#  '-13x-181',
#  '-12x-181',
#  '-11x-181',
#  '-11x-181',
#  '-10x-180',
#  '-10x-179',
#  '-10x-178',
#  '-10x-177',
#  '-10x-176',
#  '-10x-175',
#  '-10x-175',
#  '-11x-174',
#  '-12x-174',
#  '-13x-174',
#  '-14x-174',
#  '-15x-174',
#  '-16x-174',
#  '-17x-174',
#  '-18x-174',
#  '-19x-174',
#  '-20x-174',
#  '-21x-174',
#  '-22x-174',
#  '-22x-174',
#  '-23x-175',
#  '-23x-176',
#  '-23x-177',
#  '-23x-178',
#  '-23x-179',
#  '-23x-180',
#  '-23x-181',
#  '-23x-182',
#  '-23x-183',
#  '-23x-184',
#  '-23x-185',
#  '-23x-186',
#  '-23x-187',
#  '-23x-188',
#  '-23x-188',
#  '-23x-188',
#  '-23x-188',
#  '-24x-187',
#  '-25x-187',
#  '-26x-187',
#  '-27x-187',
#  '-28x-187',
#  '-29x-187',
#  '-30x-187',
#  '-31x-187',
#  '-32x-187',
#  '-33x-187',
#  '-34x-187',
#  '-35x-187',
#  '-36x-187',
#  '-37x-187',
#  '-38x-187',
#  '-39x-187',
#  '-40x-187',
#  '-40x-187',
#  '-41x-188',
#  '-41x-189',
#  '-41x-190',
#  '-41x-191',
#  '-41x-191',
#  '-41x-191',
#  '-41x-190',
#  '-41x-189',
#  '-41x-188',
#  '-41x-188',
#  '-41x-188',
#  '-41x-189',
#  '-41x-190',
#  '-41x-191',
#  '-41x-192',
#  '-41x-193',
#  '-41x-194',
#  '-41x-195',
#  '-41x-196',
#  '-41x-196',
#  '-42x-197',
#  '-43x-197',
#  '-44x-197',
#  '-45x-197',
#  '-46x-197',
#  '-47x-197',
#  '-48x-197',
#  '-48x-197',
#  '-49x-198',
#  '-49x-199',
#  '-49x-200',
#  '-49x-201',
#  '-49x-202',
#  '-49x-203',
#  '-49x-204',
#  '-49x-205',
#  '-49x-206',
#  '-49x-207',
#  '-49x-208',
#  '-49x-209',
#  '-49x-209',
#  '-49x-209',
#  '-49x-208',
#  '-49x-207',
#  '-49x-206',
#  '-49x-205',
#  '-49x-204',
#  '-49x-203',
#  '-49x-203',
#  '-50x-202',
#  '-51x-202',
#  '-52x-202',
#  '-53x-202',
#  '-54x-202',
#  '-55x-202',
#  '-56x-202',
#  '-57x-202',
#  '-58x-202',
#  '-59x-202',
#  '-60x-202',
#  '-61x-202',
#  '-62x-202',
#  '-63x-202',
#  '-63x-202',
#  '-64x-203',
#  '-64x-204',
#  '-64x-205',
#  '-64x-206',
#  '-64x-207',
#  '-64x-208',
#  '-64x-209',
#  '-64x-210',
#  '-64x-211',
#  '-64x-212',
#  '-64x-213',
#  '-64x-213',
#  '-64x-213',
#  '-64x-212',
#  '-64x-211',
#  '-64x-210',
#  '-64x-209',
#  '-64x-208',
#  '-64x-207',
#  '-64x-206',
#  '-64x-205',
#  '-64x-204',
#  '-64x-204',
#  '-64x-204',
#  '-64x-205',
#  '-64x-206',
#  '-64x-207',
#  '-64x-208',
#  '-64x-209',
#  '-64x-210',
#  '-64x-211',
#  '-64x-212',
#  '-64x-213',
#  '-64x-214',
#  '-64x-215',
#  '-64x-216',
#  '-64x-217',
#  '-64x-218',
#  '-64x-219',
#  '-64x-219',
#  '-65x-220',
#  '-66x-220',
#  '-67x-220',
#  '-68x-220',
#  '-69x-220',
#  '-70x-220',
#  '-71x-220',
#  '-72x-220',
#  '-73x-220',
#  '-74x-220',
#  '-75x-220',
#  '-76x-220',
#  '-77x-220',
#  '-77x-220',
#  '-77x-220',
#  '-76x-220',
#  '-75x-220',
#  '-75x-220',
#  '-74x-221',
#  '-74x-222',
#  '-74x-223',
#  '-74x-224',
#  '-74x-225',
#  '-74x-226',
#  '-74x-227',
#  '-74x-228',
#  '-74x-229',
#  '-74x-230',
#  '-74x-231',
#  '-74x-232',
#  '-74x-233',
#  '-74x-234',
#  '-74x-235',
#  '-74x-236',
#  '-74x-237',
#  '-74x-238',
#  '-74x-238',
#  '-75x-239',
#  '-76x-239',
#  '-77x-239',
#  '-78x-239',
#  '-79x-239',
#  '-79x-239',
#  '-80x-240',
#  '-80x-241',
#  '-80x-242',
#  '-80x-243',
#  '-80x-243',
#  '-81x-244',
#  '-82x-244',
#  '-83x-244',
#  '-84x-244',
#  '-85x-244',
#  '-86x-244',
#  '-87x-244',
#  '-88x-244',
#  '-89x-244',
#  '-90x-244',
#  '-91x-244',
#  '-92x-244',
#  '-92x-244',
#  '-93x-245',
#  '-93x-246',
#  '-93x-247',
#  '-93x-248',
#  '-93x-249',
#  '-93x-250',
#  '-93x-251',
#  '-93x-252',
#  '-93x-253',
#  '-93x-254',
#  '-93x-255',
#  '-93x-256',
#  '-93x-257',
#  '-93x-258',
#  '-93x-259',
#  '-93x-259',
#  '-93x-259',
#  '-92x-259',
#  '-91x-259',
#  '-90x-259',
#  '-89x-259',
#  '-88x-259',
#  '-87x-259',
#  '-86x-259',
#  '-85x-259',
#  '-84x-259',
#  '-83x-259',
#  '-82x-259',
#  '-81x-259',
#  '-80x-259',
#  '-80x-259',
#  '-79x-258',
#  '-79x-257',
#  '-79x-256',
#  '-79x-255',
#  '-79x-254',
#  '-79x-253',
#  '-79x-252',
#  '-79x-251',
#  '-79x-250',
#  '-79x-249',
#  '-79x-248',
#  '-79x-247',
#  '-79x-246',
#  '-79x-245',
#  '-79x-245',
#  '-80x-244',
#  '-81x-244',
#  '-82x-244',
#  '-83x-244',
#  '-84x-244',
#  '-85x-244',
#  '-86x-244',
#  '-87x-244',
#  '-88x-244',
#  '-89x-244',
#  '-90x-244',
#  '-91x-244',
#  '-92x-244',
#  '-93x-244',
#  '-94x-244',
#  '-95x-244',
#  '-96x-244',
#  '-96x-244',
#  '-97x-245',
#  '-97x-246',
#  '-97x-247',
#  '-97x-248',
#  '-97x-249',
#  '-97x-250',
#  '-97x-250',
#  '-98x-251',
#  '-99x-251',
#  '-100x-251',
#  '-101x-251',
#  '-102x-251',
#  '-103x-251',
#  '-104x-251',
#  '-105x-251',
#  '-106x-251',
#  '-107x-251',
#  '-108x-251',
#  '-109x-251',
#  '-110x-251',
#  '-110x-251',
#  '-111x-252',
#  '-111x-253',
#  '-111x-254',
#  '-111x-255',
#  '-111x-256',
#  '-111x-257',
#  '-111x-258',
#  '-111x-259',
#  '-111x-260',
#  '-111x-261',
#  '-111x-261',
#  '-112x-262',
#  '-113x-262',
#  '-114x-262',
#  '-115x-262',
#  '-116x-262',
#  '-117x-262',
#  '-117x-262',
#  '-118x-263',
#  '-118x-264',
#  '-118x-265',
#  '-118x-266',
#  '-118x-267',
#  '-118x-268',
#  '-118x-269',
#  '-118x-270',
#  '-118x-271',
#  '-118x-272',
#  '-118x-273',
#  '-118x-274',
#  '-118x-275',
#  '-118x-276',
#  '-118x-277',
#  '-118x-278',
#  '-118x-279',
#  '-118x-279',
#  '-118x-279',
#  '-118x-278',
#  '-118x-277',
#  '-118x-276',
#  '-118x-275',
#  '-118x-274',
#  '-118x-273',
#  '-118x-272',
#  '-118x-271',
#  '-118x-270',
#  '-118x-269',
#  '-118x-268',
#  '-118x-267',
#  '-118x-266',
#  '-118x-265',
#  '-118x-265',
#  '-118x-265',
#  '-118x-265',
#  '-117x-264',
#  '-116x-264',
#  '-115x-264',
#  '-114x-264',
#  '-113x-264',
#  '-112x-264',
#  '-111x-264',
#  '-110x-264',
#  '-109x-264',
#  '-108x-264',
#  '-107x-264',
#  '-106x-264',
#  '-105x-264',
#  '-104x-264',
#  '-103x-264',
#  '-102x-264',
#  '-102x-264',
#  '-102x-264',
#  '-102x-263',
#  '-102x-262',
#  '-102x-261',
#  '-102x-260',
#  '-102x-259',
#  '-102x-258',
#  '-102x-257',
#  '-102x-256',
#  '-102x-255',
#  '-102x-254',
#  '-102x-253',
#  '-102x-252',
#  '-102x-251',
#  '-102x-250',
#  '-102x-249',
#  '-102x-248',
#  '-102x-247',
#  '-102x-246',
#  '-102x-246',
#  '-101x-245',
#  '-100x-245',
#  '-100x-245']
# {'152x-13', '-33x-172', '63x-40', '38x-60', '43x-73', '133x-20', '18x-34', '-43x13', '-2x58', '-79x-257', '61x21', '-45x-153', '10x19', '14x-43', '98x-194', '-6x38', '-11x14', '27x-45', '136x-46', '109x-133', '39x-37', '70x7', '59x-203', '-29x-160', '30x-24', '109x-217', '141x-46', '-115x-264', '34x24', '91x-174', '107x-167', '108x-145', '49x-43', '-102x-259', '-35x-156', '32x22', '76x-69', '30x32', '158x-39', '85x-38', '23x-21', '-4x26', '5x62', '106x-217', '-11x16', '31x-66', '66x-198', '78x-6', '12x-39', '92x-47', '22x22', '40x15', '35x-3', '69x-191', '102x-156', '-7x46', '20x-45', '174x-29', '-8x-5', '140x-46', '87x-186', '-40x-153', '42x-156', '83x-50', '-27x11', '120x-131', '11x42', '91x-197', '36x-174', '-1x44', '68x-35', '89x-110', '38x-27', '102x-124', '129x-95', '62x-77', '9x19', '98x-187', '11x-156', '1x8', '59x-193', '-54x-152', '-1x26', '12x22', '-50x-120', '4x67', '-53x-2', '143x-48', '-15x15', '7x-28', '-101x-251', '25x-196', '121x-123', '-11x-13', '116x-145', '51x-65', '89x-145', '-42x-148', '10x-21', '-64x-134', '144x-35', '72x-201', '73x-186', '129x-92', '-68x-114', '172x-34', '45x-36', '27x-50', '-1x-9', '47x-22', '26x24', '75x12', '112x-145', '-41x-143', '13x22', '101x-148', '109x-13', '104x-151', '22x17', '62x-73', '-54x-21', '-55x-16', '144x-48', '-103x-264', '89x-38', '96x-211', '5x2', '108x-94', '23x13', '-11x28', '103x-159', '2x2', '144x-58', '108x-96', '52x6', '-48x-197', '-13x17', '-16x14', '82x-13', '41x-13', '54x0', '28x-50', '53x-55', '31x27', '158x-45', '144x-38', '-12x-181', '4x15', '10x-20', '100x-154', '-17x-174', '3x-18', '19x14', '27x-42', '14x17', '120x-124', '-56x-202', '28x-32', '149x-41', '12x12', '33x-26', '150x-52', '82x-11', '57x-77', '21x20', '-13x-174', '55x-173', '-8x0', '0x17', '2x64', '74x14', '41x3', '78x-14', '41x-14', '23x-40', '78x-68', '78x-38', '20x-14', '79x-61', '76x7', '9x-31', '24x13', '28x15', '4x-29', '40x-11', '107x-168', '65x-68', '10x12', '11x-14', '-14x-12', '-48x4', '67x-2', '100x-172', '81x-74', '147x-12', '-24x-167', '-10x-21', '91x-172', '163x-49', '33x30', '64x-2', '2x-162', '99x-9', '-39x0', '27x14', '43x-185', '98x-224', '53x-24', '149x-37', '67x10', '73x-8', '150x-50', '43x15', '-12x14', '14x-44', '55x-182', '29x-29', '66x-203', '-29x13', '-10x48', '76x-67', '147x-101', '-24x32', '-27x-172', '55x-185', '127x-104', '12x27', '31x-43', '49x-71', '76x-60', '51x-198', '65x-61', '158x-36', '81x-167', '69x-214', '172x-42', '167x-47', '91x-175', '-27x10', '25x24', '12x17', '109x-12', '110x-124', '25x-55', '101x-172', '2x29', '48x4', '74x-33', '9x22', '26x-67', '134x-58', '101x-146', '151x-39', '3x-42', '49x-72', '-2x21', '58x-53', '-3x7', '32x-8', '-69x-117', '1x-31', '11x10', '63x1', '68x-186', '80x-57', '52x8', '19x8', '15x-44', '13x17', '87x-74', '89x-197', '55x-41', '38x20', '-13x35', '37x-72', '-42x-159', '100x-153', '15x16', '41x-8', '-37x14', '29x-50', '-9x-9', '156x-36', '98x-110', '79x-76', '75x20', '-12x-17', '40x-84', '-55x-163', '81x-38', '140x-32', '133x-74', '10x15', '68x-61', '3x17', '-28x-160', '129x-68', '-62x-134', '-27x5', '109x-137', '-8x43', '48x5', '-63x-133', '72x-195', '25x21', '-28x26', '-10x11', '41x9', '26x-21', '69x-12', '97x-8', '46x-29', '-10x12', '-44x17', '138x-121', '95x-153', '33x24', '-41x-15', '120x-87', '-73x-122', '52x-30', '-42x-147', '173x-32', '72x-186', '97x-7', '47x-26', '181x-45', '120x-106', '96x-109', '9x13', '-7x45', '-1x-4', '27x16', '60x13', '-10x43', '-48x-145', '101x-102', '-7x47', '38x-63', '-18x29', '64x-40', '-30x30', '-2x-10', '3x25', '102x-228', '16x14', '96x-226', '74x-35', '5x6', '78x-7', '89x-147', '4x0', '65x-70', '-24x-166', '-39x-1', '54x3', '-8x-16', '-57x-114', '-32x-160', '138x-37', '114x-98', '2x-1', '112x-75', '75x-66', '-118x-265', '10x-27', '23x-33', '49x-44', '105x-152', '23x-164', '17x35', '40x-48', '29x-8', '8x-39', '25x-52', '15x34', '162x-33', '60x12', '121x-14', '23x41', '67x-174', '139x-96', '10x21', '0x10', '48x-35', '66x-214', '34x3', '102x-9', '171x-32', '-102x-250', '17x-34', '-4x6', ' ...
# 6384
